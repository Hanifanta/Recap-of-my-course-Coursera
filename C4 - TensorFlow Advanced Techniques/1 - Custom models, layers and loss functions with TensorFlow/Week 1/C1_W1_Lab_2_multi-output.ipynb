# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 945us/sample - loss: 187.4899 - y1_output_loss: 92.8791 - y2_output_loss: 92.9913 - y1_output_root_mean_squared_error: 9.6819 - y2_output_root_mean_squared_error: 9.6825 - val_loss: 36.2558 - val_y1_output_loss: 15.8842 - val_y2_output_loss: 20.3589 - val_y1_output_root_mean_squared_error: 3.9463 - val_y2_output_root_mean_squared_error: 4.5478
# Epoch 2/500
# 614/614 [==============================] - 0s 146us/sample - loss: 45.4278 - y1_output_loss: 14.7037 - y2_output_loss: 30.4568 - y1_output_root_mean_squared_error: 3.8418 - y2_output_root_mean_squared_error: 5.5379 - val_loss: 26.6981 - val_y1_output_loss: 10.9017 - val_y2_output_loss: 15.5137 - val_y1_output_root_mean_squared_error: 3.2991 - val_y2_output_root_mean_squared_error: 3.9766
# Epoch 3/500
# 614/614 [==============================] - 0s 138us/sample - loss: 27.7077 - y1_output_loss: 10.4292 - y2_output_loss: 17.2522 - y1_output_root_mean_squared_error: 3.2296 - y2_output_root_mean_squared_error: 4.1566 - val_loss: 30.3768 - val_y1_output_loss: 11.7724 - val_y2_output_loss: 18.7779 - val_y1_output_root_mean_squared_error: 3.3732 - val_y2_output_root_mean_squared_error: 4.3587
# Epoch 4/500
# 614/614 [==============================] - 0s 135us/sample - loss: 23.8499 - y1_output_loss: 9.5138 - y2_output_loss: 15.0085 - y1_output_root_mean_squared_error: 3.0435 - y2_output_root_mean_squared_error: 3.8193 - val_loss: 73.6707 - val_y1_output_loss: 18.1656 - val_y2_output_loss: 54.8444 - val_y1_output_root_mean_squared_error: 4.3010 - val_y2_output_root_mean_squared_error: 7.4278
# Epoch 5/500
# 614/614 [==============================] - 0s 158us/sample - loss: 23.9966 - y1_output_loss: 8.9803 - y2_output_loss: 14.8325 - y1_output_root_mean_squared_error: 3.0062 - y2_output_root_mean_squared_error: 3.8677 - val_loss: 20.8081 - val_y1_output_loss: 8.0798 - val_y2_output_loss: 12.4870 - val_y1_output_root_mean_squared_error: 2.8425 - val_y2_output_root_mean_squared_error: 3.5677
# Epoch 6/500
# 614/614 [==============================] - 0s 164us/sample - loss: 24.3056 - y1_output_loss: 9.2556 - y2_output_loss: 14.9447 - y1_output_root_mean_squared_error: 3.0439 - y2_output_root_mean_squared_error: 3.8782 - val_loss: 18.0229 - val_y1_output_loss: 7.7700 - val_y2_output_loss: 9.8812 - val_y1_output_root_mean_squared_error: 2.7924 - val_y2_output_root_mean_squared_error: 3.1977
# Epoch 7/500
# 614/614 [==============================] - 0s 140us/sample - loss: 24.9818 - y1_output_loss: 9.5070 - y2_output_loss: 15.6929 - y1_output_root_mean_squared_error: 3.0614 - y2_output_root_mean_squared_error: 3.9509 - val_loss: 42.4734 - val_y1_output_loss: 13.4052 - val_y2_output_loss: 28.6725 - val_y1_output_root_mean_squared_error: 3.6923 - val_y2_output_root_mean_squared_error: 5.3703
# Epoch 8/500
# 614/614 [==============================] - 0s 135us/sample - loss: 20.6373 - y1_output_loss: 8.2150 - y2_output_loss: 12.4984 - y1_output_root_mean_squared_error: 2.8525 - y2_output_root_mean_squared_error: 3.5356 - val_loss: 38.0320 - val_y1_output_loss: 13.0854 - val_y2_output_loss: 24.6194 - val_y1_output_root_mean_squared_error: 3.6041 - val_y2_output_root_mean_squared_error: 5.0042
# Epoch 9/500
# 614/614 [==============================] - 0s 130us/sample - loss: 21.5737 - y1_output_loss: 8.2495 - y2_output_loss: 13.2404 - y1_output_root_mean_squared_error: 2.8717 - y2_output_root_mean_squared_error: 3.6506 - val_loss: 28.1070 - val_y1_output_loss: 9.7891 - val_y2_output_loss: 18.0255 - val_y1_output_root_mean_squared_error: 3.1143 - val_y2_output_root_mean_squared_error: 4.2905
# Epoch 10/500
# 614/614 [==============================] - 0s 137us/sample - loss: 21.8927 - y1_output_loss: 8.2373 - y2_output_loss: 13.6108 - y1_output_root_mean_squared_error: 2.8710 - y2_output_root_mean_squared_error: 3.6946 - val_loss: 22.6683 - val_y1_output_loss: 7.7305 - val_y2_output_loss: 14.7985 - val_y1_output_root_mean_squared_error: 2.7720 - val_y2_output_root_mean_squared_error: 3.8710
# Epoch 11/500
# 614/614 [==============================] - 0s 137us/sample - loss: 18.9748 - y1_output_loss: 7.7192 - y2_output_loss: 11.5615 - y1_output_root_mean_squared_error: 2.7730 - y2_output_root_mean_squared_error: 3.3594 - val_loss: 81.0031 - val_y1_output_loss: 15.4876 - val_y2_output_loss: 65.1628 - val_y1_output_root_mean_squared_error: 3.9691 - val_y2_output_root_mean_squared_error: 8.0777
# Epoch 12/500
# 614/614 [==============================] - 0s 135us/sample - loss: 22.0374 - y1_output_loss: 7.8863 - y2_output_loss: 13.9705 - y1_output_root_mean_squared_error: 2.8191 - y2_output_root_mean_squared_error: 3.7537 - val_loss: 21.1018 - val_y1_output_loss: 8.4625 - val_y2_output_loss: 12.2397 - val_y1_output_root_mean_squared_error: 2.9153 - val_y2_output_root_mean_squared_error: 3.5500
# Epoch 13/500
# 614/614 [==============================] - 0s 145us/sample - loss: 20.7017 - y1_output_loss: 8.0151 - y2_output_loss: 12.7614 - y1_output_root_mean_squared_error: 2.8163 - y2_output_root_mean_squared_error: 3.5736 - val_loss: 25.6123 - val_y1_output_loss: 8.0458 - val_y2_output_loss: 17.4971 - val_y1_output_root_mean_squared_error: 2.8134 - val_y2_output_root_mean_squared_error: 4.2068
# Epoch 14/500
# 614/614 [==============================] - 0s 136us/sample - loss: 20.7908 - y1_output_loss: 7.6153 - y2_output_loss: 13.0977 - y1_output_root_mean_squared_error: 2.7556 - y2_output_root_mean_squared_error: 3.6328 - val_loss: 21.3955 - val_y1_output_loss: 8.8166 - val_y2_output_loss: 12.0317 - val_y1_output_root_mean_squared_error: 3.0045 - val_y2_output_root_mean_squared_error: 3.5169
# Epoch 15/500
# 614/614 [==============================] - 0s 130us/sample - loss: 16.5797 - y1_output_loss: 6.6259 - y2_output_loss: 9.8833 - y1_output_root_mean_squared_error: 2.5798 - y2_output_root_mean_squared_error: 3.1503 - val_loss: 17.5304 - val_y1_output_loss: 7.1190 - val_y2_output_loss: 10.1162 - val_y1_output_root_mean_squared_error: 2.6751 - val_y2_output_root_mean_squared_error: 3.2209
# Epoch 16/500
# 614/614 [==============================] - 0s 130us/sample - loss: 17.6893 - y1_output_loss: 6.7091 - y2_output_loss: 10.9815 - y1_output_root_mean_squared_error: 2.5794 - y2_output_root_mean_squared_error: 3.3220 - val_loss: 26.3824 - val_y1_output_loss: 9.3481 - val_y2_output_loss: 17.0558 - val_y1_output_root_mean_squared_error: 3.0269 - val_y2_output_root_mean_squared_error: 4.1497
# Epoch 17/500
# 614/614 [==============================] - 0s 130us/sample - loss: 17.3694 - y1_output_loss: 6.5558 - y2_output_loss: 10.6733 - y1_output_root_mean_squared_error: 2.5715 - y2_output_root_mean_squared_error: 3.2797 - val_loss: 14.0758 - val_y1_output_loss: 6.0019 - val_y2_output_loss: 7.8647 - val_y1_output_root_mean_squared_error: 2.4442 - val_y2_output_root_mean_squared_error: 2.8464
# Epoch 18/500
# 614/614 [==============================] - 0s 132us/sample - loss: 13.9699 - y1_output_loss: 5.9885 - y2_output_loss: 8.2194 - y1_output_root_mean_squared_error: 2.4232 - y2_output_root_mean_squared_error: 2.8457 - val_loss: 37.0050 - val_y1_output_loss: 13.0545 - val_y2_output_loss: 24.1200 - val_y1_output_root_mean_squared_error: 3.5732 - val_y2_output_root_mean_squared_error: 4.9231
# Epoch 19/500
# 614/614 [==============================] - 0s 130us/sample - loss: 16.1629 - y1_output_loss: 6.0119 - y2_output_loss: 10.1104 - y1_output_root_mean_squared_error: 2.4588 - y2_output_root_mean_squared_error: 3.1808 - val_loss: 22.6846 - val_y1_output_loss: 6.5573 - val_y2_output_loss: 16.1910 - val_y1_output_root_mean_squared_error: 2.5757 - val_y2_output_root_mean_squared_error: 4.0063
# Epoch 20/500
# 614/614 [==============================] - 0s 155us/sample - loss: 19.9899 - y1_output_loss: 6.5899 - y2_output_loss: 13.5453 - y1_output_root_mean_squared_error: 2.5512 - y2_output_root_mean_squared_error: 3.6717 - val_loss: 50.2262 - val_y1_output_loss: 16.4271 - val_y2_output_loss: 33.4836 - val_y1_output_root_mean_squared_error: 4.0426 - val_y2_output_root_mean_squared_error: 5.8210
# Epoch 21/500
# 614/614 [==============================] - 0s 141us/sample - loss: 16.5079 - y1_output_loss: 5.8698 - y2_output_loss: 10.7210 - y1_output_root_mean_squared_error: 2.4038 - y2_output_root_mean_squared_error: 3.2756 - val_loss: 16.9080 - val_y1_output_loss: 7.0028 - val_y2_output_loss: 9.7709 - val_y1_output_root_mean_squared_error: 2.6232 - val_y2_output_root_mean_squared_error: 3.1665
# Epoch 22/500
# 614/614 [==============================] - 0s 142us/sample - loss: 15.1516 - y1_output_loss: 5.4207 - y2_output_loss: 9.6556 - y1_output_root_mean_squared_error: 2.3354 - y2_output_root_mean_squared_error: 3.1141 - val_loss: 18.9500 - val_y1_output_loss: 8.0606 - val_y2_output_loss: 10.6189 - val_y1_output_root_mean_squared_error: 2.8685 - val_y2_output_root_mean_squared_error: 3.2744
# Epoch 23/500
# 614/614 [==============================] - 0s 130us/sample - loss: 14.8223 - y1_output_loss: 5.6698 - y2_output_loss: 9.2747 - y1_output_root_mean_squared_error: 2.3745 - y2_output_root_mean_squared_error: 3.0305 - val_loss: 13.9809 - val_y1_output_loss: 5.4027 - val_y2_output_loss: 8.2144 - val_y1_output_root_mean_squared_error: 2.3449 - val_y2_output_root_mean_squared_error: 2.9124
# Epoch 24/500
# 614/614 [==============================] - 0s 132us/sample - loss: 13.6307 - y1_output_loss: 5.2167 - y2_output_loss: 8.3370 - y1_output_root_mean_squared_error: 2.2932 - y2_output_root_mean_squared_error: 2.8934 - val_loss: 11.2919 - val_y1_output_loss: 4.3535 - val_y2_output_loss: 6.6626 - val_y1_output_root_mean_squared_error: 2.1053 - val_y2_output_root_mean_squared_error: 2.6191
# Epoch 25/500
# 614/614 [==============================] - 0s 145us/sample - loss: 12.4487 - y1_output_loss: 4.6025 - y2_output_loss: 7.7651 - y1_output_root_mean_squared_error: 2.1508 - y2_output_root_mean_squared_error: 2.7969 - val_loss: 12.2472 - val_y1_output_loss: 4.8492 - val_y2_output_loss: 7.1102 - val_y1_output_root_mean_squared_error: 2.2273 - val_y2_output_root_mean_squared_error: 2.6993
# Epoch 26/500
# 614/614 [==============================] - 0s 142us/sample - loss: 11.4431 - y1_output_loss: 4.6415 - y2_output_loss: 6.7849 - y1_output_root_mean_squared_error: 2.1484 - y2_output_root_mean_squared_error: 2.6130 - val_loss: 14.4413 - val_y1_output_loss: 4.2604 - val_y2_output_loss: 9.8575 - val_y1_output_root_mean_squared_error: 2.0872 - val_y2_output_root_mean_squared_error: 3.1757
# Epoch 27/500
# 614/614 [==============================] - 0s 138us/sample - loss: 12.2221 - y1_output_loss: 4.4843 - y2_output_loss: 7.7056 - y1_output_root_mean_squared_error: 2.1147 - y2_output_root_mean_squared_error: 2.7839 - val_loss: 10.8404 - val_y1_output_loss: 4.0843 - val_y2_output_loss: 6.5435 - val_y1_output_root_mean_squared_error: 2.0501 - val_y2_output_root_mean_squared_error: 2.5763
# Epoch 28/500
# 614/614 [==============================] - 0s 134us/sample - loss: 12.4425 - y1_output_loss: 4.5861 - y2_output_loss: 7.7785 - y1_output_root_mean_squared_error: 2.1432 - y2_output_root_mean_squared_error: 2.8017 - val_loss: 10.8895 - val_y1_output_loss: 4.1256 - val_y2_output_loss: 6.4877 - val_y1_output_root_mean_squared_error: 2.0628 - val_y2_output_root_mean_squared_error: 2.5757
# Epoch 29/500
# 614/614 [==============================] - 0s 138us/sample - loss: 12.5426 - y1_output_loss: 4.5135 - y2_output_loss: 8.0057 - y1_output_root_mean_squared_error: 2.1263 - y2_output_root_mean_squared_error: 2.8322 - val_loss: 12.2741 - val_y1_output_loss: 4.3780 - val_y2_output_loss: 7.6160 - val_y1_output_root_mean_squared_error: 2.1050 - val_y2_output_root_mean_squared_error: 2.8005
# Epoch 30/500
# 614/614 [==============================] - 0s 144us/sample - loss: 10.7006 - y1_output_loss: 4.0864 - y2_output_loss: 6.5874 - y1_output_root_mean_squared_error: 2.0248 - y2_output_root_mean_squared_error: 2.5692 - val_loss: 11.3592 - val_y1_output_loss: 3.3305 - val_y2_output_loss: 7.9434 - val_y1_output_root_mean_squared_error: 1.8453 - val_y2_output_root_mean_squared_error: 2.8203
# Epoch 31/500
# 614/614 [==============================] - 0s 138us/sample - loss: 10.4597 - y1_output_loss: 3.6969 - y2_output_loss: 6.7135 - y1_output_root_mean_squared_error: 1.9229 - y2_output_root_mean_squared_error: 2.6004 - val_loss: 11.9192 - val_y1_output_loss: 4.4510 - val_y2_output_loss: 7.3102 - val_y1_output_root_mean_squared_error: 2.1301 - val_y2_output_root_mean_squared_error: 2.7169
# Epoch 32/500
# 614/614 [==============================] - 0s 143us/sample - loss: 12.0733 - y1_output_loss: 3.8874 - y2_output_loss: 8.0908 - y1_output_root_mean_squared_error: 1.9797 - y2_output_root_mean_squared_error: 2.8555 - val_loss: 27.0641 - val_y1_output_loss: 8.1273 - val_y2_output_loss: 19.4505 - val_y1_output_root_mean_squared_error: 2.8078 - val_y2_output_root_mean_squared_error: 4.3795
# Epoch 33/500
# 614/614 [==============================] - 0s 140us/sample - loss: 18.2249 - y1_output_loss: 5.9104 - y2_output_loss: 12.1859 - y1_output_root_mean_squared_error: 2.4368 - y2_output_root_mean_squared_error: 3.5053 - val_loss: 13.0023 - val_y1_output_loss: 5.3911 - val_y2_output_loss: 7.7346 - val_y1_output_root_mean_squared_error: 2.2933 - val_y2_output_root_mean_squared_error: 2.7826
# Epoch 34/500
# 614/614 [==============================] - 0s 146us/sample - loss: 10.0241 - y1_output_loss: 3.4126 - y2_output_loss: 6.5809 - y1_output_root_mean_squared_error: 1.8526 - y2_output_root_mean_squared_error: 2.5675 - val_loss: 9.5535 - val_y1_output_loss: 3.0406 - val_y2_output_loss: 6.4037 - val_y1_output_root_mean_squared_error: 1.7704 - val_y2_output_root_mean_squared_error: 2.5336
# Epoch 35/500
# 614/614 [==============================] - 0s 137us/sample - loss: 9.8227 - y1_output_loss: 3.5584 - y2_output_loss: 6.1894 - y1_output_root_mean_squared_error: 1.8955 - y2_output_root_mean_squared_error: 2.4960 - val_loss: 8.8958 - val_y1_output_loss: 3.0680 - val_y2_output_loss: 5.6477 - val_y1_output_root_mean_squared_error: 1.7729 - val_y2_output_root_mean_squared_error: 2.3985
# Epoch 36/500
# 614/614 [==============================] - 0s 134us/sample - loss: 12.3776 - y1_output_loss: 4.1739 - y2_output_loss: 8.6172 - y1_output_root_mean_squared_error: 2.0128 - y2_output_root_mean_squared_error: 2.8855 - val_loss: 49.0889 - val_y1_output_loss: 14.6749 - val_y2_output_loss: 36.2277 - val_y1_output_root_mean_squared_error: 3.7298 - val_y2_output_root_mean_squared_error: 5.9311
# Epoch 37/500
# 614/614 [==============================] - 0s 140us/sample - loss: 11.8759 - y1_output_loss: 3.7190 - y2_output_loss: 8.0812 - y1_output_root_mean_squared_error: 1.9347 - y2_output_root_mean_squared_error: 2.8518 - val_loss: 9.4104 - val_y1_output_loss: 3.2656 - val_y2_output_loss: 6.0117 - val_y1_output_root_mean_squared_error: 1.8353 - val_y2_output_root_mean_squared_error: 2.4580
# Epoch 38/500
# 614/614 [==============================] - 0s 190us/sample - loss: 9.1996 - y1_output_loss: 3.1700 - y2_output_loss: 6.0134 - y1_output_root_mean_squared_error: 1.7821 - y2_output_root_mean_squared_error: 2.4543 - val_loss: 14.0717 - val_y1_output_loss: 5.1885 - val_y2_output_loss: 8.8995 - val_y1_output_root_mean_squared_error: 2.3013 - val_y2_output_root_mean_squared_error: 2.9624
# Epoch 39/500
# 614/614 [==============================] - 0s 140us/sample - loss: 9.0793 - y1_output_loss: 2.9387 - y2_output_loss: 6.0928 - y1_output_root_mean_squared_error: 1.7213 - y2_output_root_mean_squared_error: 2.4732 - val_loss: 10.1052 - val_y1_output_loss: 3.5318 - val_y2_output_loss: 6.6113 - val_y1_output_root_mean_squared_error: 1.8755 - val_y2_output_root_mean_squared_error: 2.5666
# Epoch 40/500
# 614/614 [==============================] - 0s 131us/sample - loss: 14.5609 - y1_output_loss: 4.3507 - y2_output_loss: 10.1592 - y1_output_root_mean_squared_error: 2.0895 - y2_output_root_mean_squared_error: 3.1930 - val_loss: 9.5933 - val_y1_output_loss: 3.2537 - val_y2_output_loss: 6.1349 - val_y1_output_root_mean_squared_error: 1.8196 - val_y2_output_root_mean_squared_error: 2.5065
# Epoch 41/500
# 614/614 [==============================] - 0s 131us/sample - loss: 8.2549 - y1_output_loss: 2.7996 - y2_output_loss: 5.4268 - y1_output_root_mean_squared_error: 1.6801 - y2_output_root_mean_squared_error: 2.3307 - val_loss: 15.4959 - val_y1_output_loss: 3.8099 - val_y2_output_loss: 11.7889 - val_y1_output_root_mean_squared_error: 1.9761 - val_y2_output_root_mean_squared_error: 3.4045
# Epoch 42/500
# 614/614 [==============================] - 0s 131us/sample - loss: 9.2139 - y1_output_loss: 2.9723 - y2_output_loss: 6.1788 - y1_output_root_mean_squared_error: 1.7283 - y2_output_root_mean_squared_error: 2.4954 - val_loss: 7.8145 - val_y1_output_loss: 2.5673 - val_y2_output_loss: 5.1010 - val_y1_output_root_mean_squared_error: 1.6307 - val_y2_output_root_mean_squared_error: 2.2705
# Epoch 43/500
# 614/614 [==============================] - 0s 132us/sample - loss: 9.6951 - y1_output_loss: 3.0696 - y2_output_loss: 6.7247 - y1_output_root_mean_squared_error: 1.7522 - y2_output_root_mean_squared_error: 2.5739 - val_loss: 24.5111 - val_y1_output_loss: 5.3906 - val_y2_output_loss: 19.8311 - val_y1_output_root_mean_squared_error: 2.3134 - val_y2_output_root_mean_squared_error: 4.3771
# Epoch 44/500
# 614/614 [==============================] - 0s 133us/sample - loss: 8.3214 - y1_output_loss: 2.7650 - y2_output_loss: 5.5051 - y1_output_root_mean_squared_error: 1.6695 - y2_output_root_mean_squared_error: 2.3525 - val_loss: 7.4107 - val_y1_output_loss: 2.3406 - val_y2_output_loss: 4.9934 - val_y1_output_root_mean_squared_error: 1.5503 - val_y2_output_root_mean_squared_error: 2.2377
# Epoch 45/500
# 614/614 [==============================] - 0s 132us/sample - loss: 7.8138 - y1_output_loss: 2.5804 - y2_output_loss: 5.2643 - y1_output_root_mean_squared_error: 1.6016 - y2_output_root_mean_squared_error: 2.2910 - val_loss: 13.6077 - val_y1_output_loss: 2.3976 - val_y2_output_loss: 10.9809 - val_y1_output_root_mean_squared_error: 1.5645 - val_y2_output_root_mean_squared_error: 3.3407
# Epoch 46/500
# 614/614 [==============================] - 0s 137us/sample - loss: 8.5476 - y1_output_loss: 2.6879 - y2_output_loss: 5.8243 - y1_output_root_mean_squared_error: 1.6370 - y2_output_root_mean_squared_error: 2.4224 - val_loss: 10.1060 - val_y1_output_loss: 3.2259 - val_y2_output_loss: 6.6989 - val_y1_output_root_mean_squared_error: 1.8011 - val_y2_output_root_mean_squared_error: 2.6195
# Epoch 47/500
# 614/614 [==============================] - 0s 137us/sample - loss: 8.1515 - y1_output_loss: 2.5475 - y2_output_loss: 5.5262 - y1_output_root_mean_squared_error: 1.6037 - y2_output_root_mean_squared_error: 2.3621 - val_loss: 7.4013 - val_y1_output_loss: 1.9749 - val_y2_output_loss: 5.2809 - val_y1_output_root_mean_squared_error: 1.4193 - val_y2_output_root_mean_squared_error: 2.3210
# Epoch 48/500
# 614/614 [==============================] - 0s 135us/sample - loss: 9.4718 - y1_output_loss: 3.1027 - y2_output_loss: 6.3691 - y1_output_root_mean_squared_error: 1.7595 - y2_output_root_mean_squared_error: 2.5251 - val_loss: 13.7816 - val_y1_output_loss: 3.5440 - val_y2_output_loss: 10.0765 - val_y1_output_root_mean_squared_error: 1.9075 - val_y2_output_root_mean_squared_error: 3.1848
# Epoch 49/500
# 614/614 [==============================] - 0s 136us/sample - loss: 8.7272 - y1_output_loss: 2.8353 - y2_output_loss: 5.8770 - y1_output_root_mean_squared_error: 1.6770 - y2_output_root_mean_squared_error: 2.4320 - val_loss: 14.2922 - val_y1_output_loss: 4.2033 - val_y2_output_loss: 10.2679 - val_y1_output_root_mean_squared_error: 2.0147 - val_y2_output_root_mean_squared_error: 3.1990
# Epoch 50/500
# 614/614 [==============================] - 0s 133us/sample - loss: 8.6682 - y1_output_loss: 2.6620 - y2_output_loss: 6.0097 - y1_output_root_mean_squared_error: 1.6266 - y2_output_root_mean_squared_error: 2.4540 - val_loss: 28.9209 - val_y1_output_loss: 9.3751 - val_y2_output_loss: 19.9459 - val_y1_output_root_mean_squared_error: 3.0186 - val_y2_output_root_mean_squared_error: 4.4508
# Epoch 51/500
# 614/614 [==============================] - 0s 133us/sample - loss: 9.4070 - y1_output_loss: 2.8205 - y2_output_loss: 6.5972 - y1_output_root_mean_squared_error: 1.6677 - y2_output_root_mean_squared_error: 2.5741 - val_loss: 9.1728 - val_y1_output_loss: 2.7653 - val_y2_output_loss: 6.2226 - val_y1_output_root_mean_squared_error: 1.6732 - val_y2_output_root_mean_squared_error: 2.5245
# Epoch 52/500
# 614/614 [==============================] - 0s 133us/sample - loss: 6.9307 - y1_output_loss: 2.3416 - y2_output_loss: 4.5470 - y1_output_root_mean_squared_error: 1.5369 - y2_output_root_mean_squared_error: 2.1374 - val_loss: 7.1470 - val_y1_output_loss: 1.8468 - val_y2_output_loss: 5.2439 - val_y1_output_root_mean_squared_error: 1.3761 - val_y2_output_root_mean_squared_error: 2.2920
# Epoch 53/500
# 614/614 [==============================] - 0s 136us/sample - loss: 9.1568 - y1_output_loss: 2.9827 - y2_output_loss: 6.1367 - y1_output_root_mean_squared_error: 1.7309 - y2_output_root_mean_squared_error: 2.4821 - val_loss: 6.8926 - val_y1_output_loss: 2.0288 - val_y2_output_loss: 4.8159 - val_y1_output_root_mean_squared_error: 1.4430 - val_y2_output_root_mean_squared_error: 2.1932
# Epoch 54/500
# 614/614 [==============================] - 0s 131us/sample - loss: 8.1311 - y1_output_loss: 2.4839 - y2_output_loss: 5.5780 - y1_output_root_mean_squared_error: 1.5827 - y2_output_root_mean_squared_error: 2.3720 - val_loss: 8.0908 - val_y1_output_loss: 2.0000 - val_y2_output_loss: 5.8723 - val_y1_output_root_mean_squared_error: 1.4199 - val_y2_output_root_mean_squared_error: 2.4647
# Epoch 55/500
# 614/614 [==============================] - 0s 135us/sample - loss: 7.0635 - y1_output_loss: 2.2790 - y2_output_loss: 4.7960 - y1_output_root_mean_squared_error: 1.5149 - y2_output_root_mean_squared_error: 2.1837 - val_loss: 8.8438 - val_y1_output_loss: 2.0761 - val_y2_output_loss: 6.7976 - val_y1_output_root_mean_squared_error: 1.4628 - val_y2_output_root_mean_squared_error: 2.5892
# Epoch 56/500
# 614/614 [==============================] - 0s 140us/sample - loss: 6.8243 - y1_output_loss: 2.2352 - y2_output_loss: 4.6365 - y1_output_root_mean_squared_error: 1.4955 - y2_output_root_mean_squared_error: 2.1419 - val_loss: 26.8791 - val_y1_output_loss: 6.5428 - val_y2_output_loss: 21.0130 - val_y1_output_root_mean_squared_error: 2.4941 - val_y2_output_root_mean_squared_error: 4.5451
# Epoch 57/500
# 614/614 [==============================] - 0s 136us/sample - loss: 7.5983 - y1_output_loss: 2.3643 - y2_output_loss: 5.2390 - y1_output_root_mean_squared_error: 1.5421 - y2_output_root_mean_squared_error: 2.2848 - val_loss: 12.0525 - val_y1_output_loss: 2.5392 - val_y2_output_loss: 9.2619 - val_y1_output_root_mean_squared_error: 1.6108 - val_y2_output_root_mean_squared_error: 3.0753
# Epoch 58/500
# 614/614 [==============================] - 0s 133us/sample - loss: 7.8116 - y1_output_loss: 2.5428 - y2_output_loss: 5.2647 - y1_output_root_mean_squared_error: 1.5932 - y2_output_root_mean_squared_error: 2.2964 - val_loss: 7.9445 - val_y1_output_loss: 2.6942 - val_y2_output_loss: 5.3763 - val_y1_output_root_mean_squared_error: 1.6197 - val_y2_output_root_mean_squared_error: 2.3067
# Epoch 59/500
# 614/614 [==============================] - 0s 130us/sample - loss: 7.3396 - y1_output_loss: 2.3332 - y2_output_loss: 5.0271 - y1_output_root_mean_squared_error: 1.5241 - y2_output_root_mean_squared_error: 2.2398 - val_loss: 6.0949 - val_y1_output_loss: 1.6313 - val_y2_output_loss: 4.3823 - val_y1_output_root_mean_squared_error: 1.2937 - val_y2_output_root_mean_squared_error: 2.1027
# Epoch 60/500
# 614/614 [==============================] - 0s 127us/sample - loss: 8.6021 - y1_output_loss: 2.5190 - y2_output_loss: 6.1283 - y1_output_root_mean_squared_error: 1.5827 - y2_output_root_mean_squared_error: 2.4692 - val_loss: 10.5540 - val_y1_output_loss: 2.5387 - val_y2_output_loss: 7.8741 - val_y1_output_root_mean_squared_error: 1.5957 - val_y2_output_root_mean_squared_error: 2.8298
# Epoch 61/500
# 614/614 [==============================] - 0s 128us/sample - loss: 7.0845 - y1_output_loss: 2.2929 - y2_output_loss: 4.7688 - y1_output_root_mean_squared_error: 1.5213 - y2_output_root_mean_squared_error: 2.1841 - val_loss: 6.3375 - val_y1_output_loss: 1.7085 - val_y2_output_loss: 4.6554 - val_y1_output_root_mean_squared_error: 1.3184 - val_y2_output_root_mean_squared_error: 2.1446
# Epoch 62/500
# 614/614 [==============================] - 0s 129us/sample - loss: 7.2054 - y1_output_loss: 2.3723 - y2_output_loss: 4.7916 - y1_output_root_mean_squared_error: 1.5402 - y2_output_root_mean_squared_error: 2.1985 - val_loss: 6.0739 - val_y1_output_loss: 1.6481 - val_y2_output_loss: 4.4414 - val_y1_output_root_mean_squared_error: 1.2996 - val_y2_output_root_mean_squared_error: 2.0940
# Epoch 63/500
# 614/614 [==============================] - 0s 136us/sample - loss: 7.2990 - y1_output_loss: 2.3224 - y2_output_loss: 5.0316 - y1_output_root_mean_squared_error: 1.5165 - y2_output_root_mean_squared_error: 2.2359 - val_loss: 18.8163 - val_y1_output_loss: 4.9856 - val_y2_output_loss: 13.9232 - val_y1_output_root_mean_squared_error: 2.2179 - val_y2_output_root_mean_squared_error: 3.7279
# Epoch 64/500
# 614/614 [==============================] - 0s 127us/sample - loss: 10.2112 - y1_output_loss: 2.7815 - y2_output_loss: 7.3512 - y1_output_root_mean_squared_error: 1.6757 - y2_output_root_mean_squared_error: 2.7209 - val_loss: 7.6070 - val_y1_output_loss: 2.7429 - val_y2_output_loss: 4.9012 - val_y1_output_root_mean_squared_error: 1.6564 - val_y2_output_root_mean_squared_error: 2.2053
# Epoch 65/500
# 614/614 [==============================] - 0s 128us/sample - loss: 12.4218 - y1_output_loss: 4.0283 - y2_output_loss: 8.3501 - y1_output_root_mean_squared_error: 2.0110 - y2_output_root_mean_squared_error: 2.8944 - val_loss: 11.0739 - val_y1_output_loss: 3.4595 - val_y2_output_loss: 7.8428 - val_y1_output_root_mean_squared_error: 1.8280 - val_y2_output_root_mean_squared_error: 2.7807
# Epoch 66/500
# 614/614 [==============================] - 0s 138us/sample - loss: 6.6587 - y1_output_loss: 2.2167 - y2_output_loss: 4.4380 - y1_output_root_mean_squared_error: 1.4775 - y2_output_root_mean_squared_error: 2.1156 - val_loss: 6.1873 - val_y1_output_loss: 1.7704 - val_y2_output_loss: 4.3458 - val_y1_output_root_mean_squared_error: 1.3512 - val_y2_output_root_mean_squared_error: 2.0884
# Epoch 67/500
# 614/614 [==============================] - 0s 135us/sample - loss: 8.0577 - y1_output_loss: 2.4941 - y2_output_loss: 5.5277 - y1_output_root_mean_squared_error: 1.5815 - y2_output_root_mean_squared_error: 2.3573 - val_loss: 7.7638 - val_y1_output_loss: 2.9046 - val_y2_output_loss: 4.8079 - val_y1_output_root_mean_squared_error: 1.7058 - val_y2_output_root_mean_squared_error: 2.2032
# Epoch 68/500
# 614/614 [==============================] - 0s 128us/sample - loss: 7.8265 - y1_output_loss: 2.6421 - y2_output_loss: 5.1588 - y1_output_root_mean_squared_error: 1.6237 - y2_output_root_mean_squared_error: 2.2782 - val_loss: 5.8809 - val_y1_output_loss: 1.6973 - val_y2_output_loss: 4.1674 - val_y1_output_root_mean_squared_error: 1.3188 - val_y2_output_root_mean_squared_error: 2.0351
# Epoch 69/500
# 614/614 [==============================] - 0s 128us/sample - loss: 7.6799 - y1_output_loss: 2.2479 - y2_output_loss: 5.4127 - y1_output_root_mean_squared_error: 1.4979 - y2_output_root_mean_squared_error: 2.3316 - val_loss: 5.6872 - val_y1_output_loss: 1.4879 - val_y2_output_loss: 4.1530 - val_y1_output_root_mean_squared_error: 1.2377 - val_y2_output_root_mean_squared_error: 2.0385
# Epoch 70/500
# 614/614 [==============================] - 0s 129us/sample - loss: 7.0298 - y1_output_loss: 2.0924 - y2_output_loss: 4.9020 - y1_output_root_mean_squared_error: 1.4446 - y2_output_root_mean_squared_error: 2.2232 - val_loss: 9.2438 - val_y1_output_loss: 2.0063 - val_y2_output_loss: 7.0764 - val_y1_output_root_mean_squared_error: 1.4215 - val_y2_output_root_mean_squared_error: 2.6876
# Epoch 71/500
# 614/614 [==============================] - 0s 132us/sample - loss: 6.4834 - y1_output_loss: 1.8958 - y2_output_loss: 4.5682 - y1_output_root_mean_squared_error: 1.3780 - y2_output_root_mean_squared_error: 2.1412 - val_loss: 6.3485 - val_y1_output_loss: 1.5278 - val_y2_output_loss: 4.7444 - val_y1_output_root_mean_squared_error: 1.2433 - val_y2_output_root_mean_squared_error: 2.1915
# Epoch 72/500
# 614/614 [==============================] - 0s 137us/sample - loss: 6.0575 - y1_output_loss: 1.8635 - y2_output_loss: 4.1633 - y1_output_root_mean_squared_error: 1.3698 - y2_output_root_mean_squared_error: 2.0448 - val_loss: 5.4073 - val_y1_output_loss: 1.4569 - val_y2_output_loss: 3.8927 - val_y1_output_root_mean_squared_error: 1.2232 - val_y2_output_root_mean_squared_error: 1.9777
# Epoch 73/500
# 614/614 [==============================] - 0s 127us/sample - loss: 5.7532 - y1_output_loss: 1.7571 - y2_output_loss: 3.9542 - y1_output_root_mean_squared_error: 1.3301 - y2_output_root_mean_squared_error: 1.9960 - val_loss: 9.6839 - val_y1_output_loss: 2.2481 - val_y2_output_loss: 7.4523 - val_y1_output_root_mean_squared_error: 1.5243 - val_y2_output_root_mean_squared_error: 2.7130
# Epoch 74/500
# 614/614 [==============================] - 0s 126us/sample - loss: 6.3896 - y1_output_loss: 1.7997 - y2_output_loss: 4.5361 - y1_output_root_mean_squared_error: 1.3469 - y2_output_root_mean_squared_error: 2.1390 - val_loss: 5.3519 - val_y1_output_loss: 1.4293 - val_y2_output_loss: 3.9048 - val_y1_output_root_mean_squared_error: 1.2024 - val_y2_output_root_mean_squared_error: 1.9764
# Epoch 75/500
# 614/614 [==============================] - 0s 136us/sample - loss: 5.7889 - y1_output_loss: 1.7226 - y2_output_loss: 4.1717 - y1_output_root_mean_squared_error: 1.3090 - y2_output_root_mean_squared_error: 2.0187 - val_loss: 18.0804 - val_y1_output_loss: 3.0779 - val_y2_output_loss: 15.5717 - val_y1_output_root_mean_squared_error: 1.7426 - val_y2_output_root_mean_squared_error: 3.8786
# Epoch 76/500
# 614/614 [==============================] - 0s 130us/sample - loss: 7.0473 - y1_output_loss: 2.0616 - y2_output_loss: 5.0342 - y1_output_root_mean_squared_error: 1.4332 - y2_output_root_mean_squared_error: 2.2345 - val_loss: 10.4307 - val_y1_output_loss: 3.0219 - val_y2_output_loss: 7.5878 - val_y1_output_root_mean_squared_error: 1.7410 - val_y2_output_root_mean_squared_error: 2.7203
# Epoch 77/500
# 614/614 [==============================] - 0s 135us/sample - loss: 7.8547 - y1_output_loss: 2.3737 - y2_output_loss: 5.4415 - y1_output_root_mean_squared_error: 1.5410 - y2_output_root_mean_squared_error: 2.3410 - val_loss: 8.0973 - val_y1_output_loss: 1.8988 - val_y2_output_loss: 6.2652 - val_y1_output_root_mean_squared_error: 1.3578 - val_y2_output_root_mean_squared_error: 2.5007
# Epoch 78/500
# 614/614 [==============================] - 0s 140us/sample - loss: 7.3921 - y1_output_loss: 2.1795 - y2_output_loss: 5.1667 - y1_output_root_mean_squared_error: 1.4788 - y2_output_root_mean_squared_error: 2.2815 - val_loss: 5.8038 - val_y1_output_loss: 1.6222 - val_y2_output_loss: 4.1484 - val_y1_output_root_mean_squared_error: 1.2715 - val_y2_output_root_mean_squared_error: 2.0462
# Epoch 79/500
# 614/614 [==============================] - 0s 138us/sample - loss: 6.6827 - y1_output_loss: 1.9442 - y2_output_loss: 4.6945 - y1_output_root_mean_squared_error: 1.3969 - y2_output_root_mean_squared_error: 2.1752 - val_loss: 4.7622 - val_y1_output_loss: 1.1306 - val_y2_output_loss: 3.5919 - val_y1_output_root_mean_squared_error: 1.0744 - val_y2_output_root_mean_squared_error: 1.8995
# Epoch 80/500
# 614/614 [==============================] - 0s 136us/sample - loss: 5.6349 - y1_output_loss: 1.5440 - y2_output_loss: 4.0706 - y1_output_root_mean_squared_error: 1.2411 - y2_output_root_mean_squared_error: 2.0235 - val_loss: 7.8938 - val_y1_output_loss: 2.6545 - val_y2_output_loss: 5.2554 - val_y1_output_root_mean_squared_error: 1.6394 - val_y2_output_root_mean_squared_error: 2.2817
# Epoch 81/500
# 614/614 [==============================] - 0s 139us/sample - loss: 5.4901 - y1_output_loss: 1.5706 - y2_output_loss: 3.9457 - y1_output_root_mean_squared_error: 1.2508 - y2_output_root_mean_squared_error: 1.9813 - val_loss: 14.7331 - val_y1_output_loss: 1.7017 - val_y2_output_loss: 12.8677 - val_y1_output_root_mean_squared_error: 1.2996 - val_y2_output_root_mean_squared_error: 3.6117
# Epoch 82/500
# 614/614 [==============================] - 0s 139us/sample - loss: 5.0345 - y1_output_loss: 1.4228 - y2_output_loss: 3.5952 - y1_output_root_mean_squared_error: 1.1963 - y2_output_root_mean_squared_error: 1.8983 - val_loss: 12.3748 - val_y1_output_loss: 3.7793 - val_y2_output_loss: 9.2415 - val_y1_output_root_mean_squared_error: 1.9021 - val_y2_output_root_mean_squared_error: 2.9592
# Epoch 83/500
# 614/614 [==============================] - 0s 138us/sample - loss: 5.9027 - y1_output_loss: 1.8014 - y2_output_loss: 4.1392 - y1_output_root_mean_squared_error: 1.3478 - y2_output_root_mean_squared_error: 2.0214 - val_loss: 16.8424 - val_y1_output_loss: 2.7272 - val_y2_output_loss: 14.3450 - val_y1_output_root_mean_squared_error: 1.6683 - val_y2_output_root_mean_squared_error: 3.7496
# Epoch 84/500
# 614/614 [==============================] - 0s 134us/sample - loss: 6.6970 - y1_output_loss: 1.7857 - y2_output_loss: 4.9141 - y1_output_root_mean_squared_error: 1.3404 - y2_output_root_mean_squared_error: 2.2137 - val_loss: 7.2862 - val_y1_output_loss: 1.5654 - val_y2_output_loss: 6.0356 - val_y1_output_root_mean_squared_error: 1.2421 - val_y2_output_root_mean_squared_error: 2.3966
# Epoch 85/500
# 614/614 [==============================] - 0s 134us/sample - loss: 7.0154 - y1_output_loss: 1.9593 - y2_output_loss: 5.0176 - y1_output_root_mean_squared_error: 1.4015 - y2_output_root_mean_squared_error: 2.2475 - val_loss: 8.7357 - val_y1_output_loss: 2.3069 - val_y2_output_loss: 6.3802 - val_y1_output_root_mean_squared_error: 1.5001 - val_y2_output_root_mean_squared_error: 2.5467
# Epoch 86/500
# 614/614 [==============================] - 0s 131us/sample - loss: 4.8430 - y1_output_loss: 1.4116 - y2_output_loss: 3.3965 - y1_output_root_mean_squared_error: 1.1893 - y2_output_root_mean_squared_error: 1.8516 - val_loss: 5.6807 - val_y1_output_loss: 1.3950 - val_y2_output_loss: 4.3250 - val_y1_output_root_mean_squared_error: 1.1536 - val_y2_output_root_mean_squared_error: 2.0857
# Epoch 87/500
# 614/614 [==============================] - 0s 132us/sample - loss: 4.6701 - y1_output_loss: 1.2495 - y2_output_loss: 3.3951 - y1_output_root_mean_squared_error: 1.1203 - y2_output_root_mean_squared_error: 1.8480 - val_loss: 4.7944 - val_y1_output_loss: 1.4357 - val_y2_output_loss: 3.2959 - val_y1_output_root_mean_squared_error: 1.2028 - val_y2_output_root_mean_squared_error: 1.8297
# Epoch 88/500
# 614/614 [==============================] - 0s 132us/sample - loss: 4.6568 - y1_output_loss: 1.2431 - y2_output_loss: 3.3766 - y1_output_root_mean_squared_error: 1.1192 - y2_output_root_mean_squared_error: 1.8451 - val_loss: 3.8840 - val_y1_output_loss: 0.9418 - val_y2_output_loss: 2.9577 - val_y1_output_root_mean_squared_error: 0.9616 - val_y2_output_root_mean_squared_error: 1.7202
# Epoch 89/500
# 614/614 [==============================] - 0s 128us/sample - loss: 4.1113 - y1_output_loss: 1.0140 - y2_output_loss: 3.0892 - y1_output_root_mean_squared_error: 1.0073 - y2_output_root_mean_squared_error: 1.7597 - val_loss: 7.1278 - val_y1_output_loss: 1.1829 - val_y2_output_loss: 5.8705 - val_y1_output_root_mean_squared_error: 1.0908 - val_y2_output_root_mean_squared_error: 2.4368
# Epoch 90/500
# 614/614 [==============================] - 0s 131us/sample - loss: 5.4555 - y1_output_loss: 1.4520 - y2_output_loss: 3.9866 - y1_output_root_mean_squared_error: 1.2092 - y2_output_root_mean_squared_error: 1.9983 - val_loss: 4.1529 - val_y1_output_loss: 1.0693 - val_y2_output_loss: 3.1059 - val_y1_output_root_mean_squared_error: 1.0455 - val_y2_output_root_mean_squared_error: 1.7492
# Epoch 91/500
# 614/614 [==============================] - 0s 130us/sample - loss: 4.7187 - y1_output_loss: 1.2501 - y2_output_loss: 3.4835 - y1_output_root_mean_squared_error: 1.1221 - y2_output_root_mean_squared_error: 1.8600 - val_loss: 7.4544 - val_y1_output_loss: 1.4058 - val_y2_output_loss: 6.1200 - val_y1_output_root_mean_squared_error: 1.1950 - val_y2_output_root_mean_squared_error: 2.4548
# Epoch 92/500
# 614/614 [==============================] - 0s 126us/sample - loss: 4.0505 - y1_output_loss: 0.8631 - y2_output_loss: 3.2556 - y1_output_root_mean_squared_error: 0.9280 - y2_output_root_mean_squared_error: 1.7859 - val_loss: 11.4393 - val_y1_output_loss: 1.7635 - val_y2_output_loss: 9.6409 - val_y1_output_root_mean_squared_error: 1.3457 - val_y2_output_root_mean_squared_error: 3.1029
# Epoch 93/500
# 614/614 [==============================] - 0s 138us/sample - loss: 5.1152 - y1_output_loss: 1.4065 - y2_output_loss: 3.6958 - y1_output_root_mean_squared_error: 1.1849 - y2_output_root_mean_squared_error: 1.9264 - val_loss: 4.8494 - val_y1_output_loss: 1.7287 - val_y2_output_loss: 3.1464 - val_y1_output_root_mean_squared_error: 1.3030 - val_y2_output_root_mean_squared_error: 1.7752
# Epoch 94/500
# 614/614 [==============================] - 0s 137us/sample - loss: 3.6777 - y1_output_loss: 0.9658 - y2_output_loss: 2.7096 - y1_output_root_mean_squared_error: 0.9765 - y2_output_root_mean_squared_error: 1.6505 - val_loss: 3.8835 - val_y1_output_loss: 0.6222 - val_y2_output_loss: 3.3539 - val_y1_output_root_mean_squared_error: 0.7893 - val_y2_output_root_mean_squared_error: 1.8057
# Epoch 95/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.6327 - y1_output_loss: 0.9463 - y2_output_loss: 2.6862 - y1_output_root_mean_squared_error: 0.9641 - y2_output_root_mean_squared_error: 1.6441 - val_loss: 4.3932 - val_y1_output_loss: 0.7108 - val_y2_output_loss: 3.6614 - val_y1_output_root_mean_squared_error: 0.8343 - val_y2_output_root_mean_squared_error: 1.9228
# Epoch 96/500
# 614/614 [==============================] - 0s 133us/sample - loss: 6.1321 - y1_output_loss: 1.4366 - y2_output_loss: 4.6760 - y1_output_root_mean_squared_error: 1.2030 - y2_output_root_mean_squared_error: 2.1645 - val_loss: 4.1790 - val_y1_output_loss: 0.7465 - val_y2_output_loss: 3.3633 - val_y1_output_root_mean_squared_error: 0.8554 - val_y2_output_root_mean_squared_error: 1.8567
# Epoch 97/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.1918 - y1_output_loss: 0.9972 - y2_output_loss: 3.1701 - y1_output_root_mean_squared_error: 1.0021 - y2_output_root_mean_squared_error: 1.7854 - val_loss: 5.9478 - val_y1_output_loss: 1.2989 - val_y2_output_loss: 4.6645 - val_y1_output_root_mean_squared_error: 1.1500 - val_y2_output_root_mean_squared_error: 2.1506
# Epoch 98/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.8814 - y1_output_loss: 0.8677 - y2_output_loss: 2.9862 - y1_output_root_mean_squared_error: 0.9349 - y2_output_root_mean_squared_error: 1.7342 - val_loss: 3.4175 - val_y1_output_loss: 0.6516 - val_y2_output_loss: 2.7314 - val_y1_output_root_mean_squared_error: 0.8065 - val_y2_output_root_mean_squared_error: 1.6635
# Epoch 99/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.4789 - y1_output_loss: 0.7968 - y2_output_loss: 2.7095 - y1_output_root_mean_squared_error: 0.8776 - y2_output_root_mean_squared_error: 1.6458 - val_loss: 8.5675 - val_y1_output_loss: 3.3887 - val_y2_output_loss: 5.5313 - val_y1_output_root_mean_squared_error: 1.8027 - val_y2_output_root_mean_squared_error: 2.3060
# Epoch 100/500
# 614/614 [==============================] - 0s 140us/sample - loss: 4.9289 - y1_output_loss: 1.0560 - y2_output_loss: 3.8406 - y1_output_root_mean_squared_error: 1.0304 - y2_output_root_mean_squared_error: 1.9665 - val_loss: 3.1718 - val_y1_output_loss: 0.5616 - val_y2_output_loss: 2.5850 - val_y1_output_root_mean_squared_error: 0.7457 - val_y2_output_root_mean_squared_error: 1.6173
# Epoch 101/500
# 614/614 [==============================] - 0s 137us/sample - loss: 4.1523 - y1_output_loss: 0.9116 - y2_output_loss: 3.3140 - y1_output_root_mean_squared_error: 0.9452 - y2_output_root_mean_squared_error: 1.8053 - val_loss: 12.7558 - val_y1_output_loss: 4.6578 - val_y2_output_loss: 8.5798 - val_y1_output_root_mean_squared_error: 2.1098 - val_y2_output_root_mean_squared_error: 2.8818
# Epoch 102/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.6471 - y1_output_loss: 0.9409 - y2_output_loss: 2.8590 - y1_output_root_mean_squared_error: 0.9533 - y2_output_root_mean_squared_error: 1.6548 - val_loss: 32.2729 - val_y1_output_loss: 11.3820 - val_y2_output_loss: 22.7236 - val_y1_output_root_mean_squared_error: 3.2382 - val_y2_output_root_mean_squared_error: 4.6677
# Epoch 103/500
# 614/614 [==============================] - 0s 129us/sample - loss: 8.5496 - y1_output_loss: 2.5784 - y2_output_loss: 5.8945 - y1_output_root_mean_squared_error: 1.6133 - y2_output_root_mean_squared_error: 2.4386 - val_loss: 3.2242 - val_y1_output_loss: 0.7271 - val_y2_output_loss: 2.4826 - val_y1_output_root_mean_squared_error: 0.8501 - val_y2_output_root_mean_squared_error: 1.5816
# Epoch 104/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.2023 - y1_output_loss: 0.7378 - y2_output_loss: 2.4519 - y1_output_root_mean_squared_error: 0.8627 - y2_output_root_mean_squared_error: 1.5678 - val_loss: 3.3849 - val_y1_output_loss: 0.6108 - val_y2_output_loss: 2.7904 - val_y1_output_root_mean_squared_error: 0.7609 - val_y2_output_root_mean_squared_error: 1.6751
# Epoch 105/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.6721 - y1_output_loss: 0.6171 - y2_output_loss: 2.0480 - y1_output_root_mean_squared_error: 0.7875 - y2_output_root_mean_squared_error: 1.4325 - val_loss: 3.0590 - val_y1_output_loss: 0.7881 - val_y2_output_loss: 2.3410 - val_y1_output_root_mean_squared_error: 0.8681 - val_y2_output_root_mean_squared_error: 1.5184
# Epoch 106/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.3750 - y1_output_loss: 0.8895 - y2_output_loss: 3.4746 - y1_output_root_mean_squared_error: 0.9452 - y2_output_root_mean_squared_error: 1.8659 - val_loss: 4.9704 - val_y1_output_loss: 1.2955 - val_y2_output_loss: 3.8015 - val_y1_output_root_mean_squared_error: 1.1285 - val_y2_output_root_mean_squared_error: 1.9227
# Epoch 107/500
# 614/614 [==============================] - 0s 153us/sample - loss: 2.9228 - y1_output_loss: 0.6831 - y2_output_loss: 2.2205 - y1_output_root_mean_squared_error: 0.8258 - y2_output_root_mean_squared_error: 1.4970 - val_loss: 2.6853 - val_y1_output_loss: 0.5042 - val_y2_output_loss: 2.1784 - val_y1_output_root_mean_squared_error: 0.7013 - val_y2_output_root_mean_squared_error: 1.4810
# Epoch 108/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.6894 - y1_output_loss: 0.6178 - y2_output_loss: 2.0610 - y1_output_root_mean_squared_error: 0.7883 - y2_output_root_mean_squared_error: 1.4381 - val_loss: 2.5011 - val_y1_output_loss: 0.5286 - val_y2_output_loss: 2.0078 - val_y1_output_root_mean_squared_error: 0.7274 - val_y2_output_root_mean_squared_error: 1.4043
# Epoch 109/500
# 614/614 [==============================] - 0s 185us/sample - loss: 3.3668 - y1_output_loss: 0.7944 - y2_output_loss: 2.5493 - y1_output_root_mean_squared_error: 0.8939 - y2_output_root_mean_squared_error: 1.6024 - val_loss: 2.7179 - val_y1_output_loss: 0.5864 - val_y2_output_loss: 2.1698 - val_y1_output_root_mean_squared_error: 0.7518 - val_y2_output_root_mean_squared_error: 1.4672
# Epoch 110/500
# 614/614 [==============================] - 0s 140us/sample - loss: 3.1084 - y1_output_loss: 0.6225 - y2_output_loss: 2.4645 - y1_output_root_mean_squared_error: 0.7889 - y2_output_root_mean_squared_error: 1.5767 - val_loss: 3.0188 - val_y1_output_loss: 0.7716 - val_y2_output_loss: 2.3147 - val_y1_output_root_mean_squared_error: 0.8737 - val_y2_output_root_mean_squared_error: 1.5018
# Epoch 111/500
# 614/614 [==============================] - 0s 137us/sample - loss: 3.0534 - y1_output_loss: 0.6555 - y2_output_loss: 2.3806 - y1_output_root_mean_squared_error: 0.8123 - y2_output_root_mean_squared_error: 1.5471 - val_loss: 3.0519 - val_y1_output_loss: 0.6144 - val_y2_output_loss: 2.4769 - val_y1_output_root_mean_squared_error: 0.7638 - val_y2_output_root_mean_squared_error: 1.5711
# Epoch 112/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.3614 - y1_output_loss: 0.7079 - y2_output_loss: 2.6339 - y1_output_root_mean_squared_error: 0.8395 - y2_output_root_mean_squared_error: 1.6299 - val_loss: 2.3671 - val_y1_output_loss: 0.5002 - val_y2_output_loss: 1.8752 - val_y1_output_root_mean_squared_error: 0.7118 - val_y2_output_root_mean_squared_error: 1.3640
# Epoch 113/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.0575 - y1_output_loss: 0.7066 - y2_output_loss: 2.3328 - y1_output_root_mean_squared_error: 0.8380 - y2_output_root_mean_squared_error: 1.5347 - val_loss: 2.9941 - val_y1_output_loss: 0.5866 - val_y2_output_loss: 2.4504 - val_y1_output_root_mean_squared_error: 0.7626 - val_y2_output_root_mean_squared_error: 1.5532
# Epoch 114/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.4763 - y1_output_loss: 0.7688 - y2_output_loss: 2.6790 - y1_output_root_mean_squared_error: 0.8804 - y2_output_root_mean_squared_error: 1.6435 - val_loss: 2.5473 - val_y1_output_loss: 0.4426 - val_y2_output_loss: 2.0763 - val_y1_output_root_mean_squared_error: 0.6593 - val_y2_output_root_mean_squared_error: 1.4535
# Epoch 115/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.4743 - y1_output_loss: 0.8950 - y2_output_loss: 2.5603 - y1_output_root_mean_squared_error: 0.9499 - y2_output_root_mean_squared_error: 1.6037 - val_loss: 2.5262 - val_y1_output_loss: 0.5129 - val_y2_output_loss: 2.0128 - val_y1_output_root_mean_squared_error: 0.7074 - val_y2_output_root_mean_squared_error: 1.4233
# Epoch 116/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.1313 - y1_output_loss: 0.7672 - y2_output_loss: 2.3430 - y1_output_root_mean_squared_error: 0.8775 - y2_output_root_mean_squared_error: 1.5367 - val_loss: 2.3177 - val_y1_output_loss: 0.5343 - val_y2_output_loss: 1.7976 - val_y1_output_root_mean_squared_error: 0.7155 - val_y2_output_root_mean_squared_error: 1.3438
# Epoch 117/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.7236 - y1_output_loss: 0.8498 - y2_output_loss: 2.8516 - y1_output_root_mean_squared_error: 0.9253 - y2_output_root_mean_squared_error: 1.6933 - val_loss: 3.5680 - val_y1_output_loss: 0.5407 - val_y2_output_loss: 2.9662 - val_y1_output_root_mean_squared_error: 0.7259 - val_y2_output_root_mean_squared_error: 1.7439
# Epoch 118/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.3621 - y1_output_loss: 0.5063 - y2_output_loss: 1.8399 - y1_output_root_mean_squared_error: 0.7127 - y2_output_root_mean_squared_error: 1.3617 - val_loss: 3.0031 - val_y1_output_loss: 0.8759 - val_y2_output_loss: 2.1635 - val_y1_output_root_mean_squared_error: 0.9060 - val_y2_output_root_mean_squared_error: 1.4772
# Epoch 119/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.7992 - y1_output_loss: 0.8882 - y2_output_loss: 2.9319 - y1_output_root_mean_squared_error: 0.9462 - y2_output_root_mean_squared_error: 1.7041 - val_loss: 4.0329 - val_y1_output_loss: 0.6083 - val_y2_output_loss: 3.4162 - val_y1_output_root_mean_squared_error: 0.7832 - val_y2_output_root_mean_squared_error: 1.8492
# Epoch 120/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.1936 - y1_output_loss: 0.7295 - y2_output_loss: 2.4391 - y1_output_root_mean_squared_error: 0.8566 - y2_output_root_mean_squared_error: 1.5684 - val_loss: 2.2385 - val_y1_output_loss: 0.4121 - val_y2_output_loss: 1.8091 - val_y1_output_root_mean_squared_error: 0.6380 - val_y2_output_root_mean_squared_error: 1.3533
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.4210 - y1_output_loss: 0.1260 - y2_output_loss: 0.2937 - y1_output_root_mean_squared_error: 0.3563 - y2_output_root_mean_squared_error: 0.5423 - val_loss: 0.9519 - val_y1_output_loss: 0.2236 - val_y2_output_loss: 0.7143 - val_y1_output_root_mean_squared_error: 0.4726 - val_y2_output_root_mean_squared_error: 0.8535
# Epoch 462/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.4552 - y1_output_loss: 0.1144 - y2_output_loss: 0.3393 - y1_output_root_mean_squared_error: 0.3395 - y2_output_root_mean_squared_error: 0.5831 - val_loss: 0.9430 - val_y1_output_loss: 0.2304 - val_y2_output_loss: 0.7103 - val_y1_output_root_mean_squared_error: 0.4738 - val_y2_output_root_mean_squared_error: 0.8476
# Epoch 463/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.4692 - y1_output_loss: 0.1395 - y2_output_loss: 0.3271 - y1_output_root_mean_squared_error: 0.3751 - y2_output_root_mean_squared_error: 0.5731 - val_loss: 0.8652 - val_y1_output_loss: 0.2104 - val_y2_output_loss: 0.6422 - val_y1_output_root_mean_squared_error: 0.4548 - val_y2_output_root_mean_squared_error: 0.8114
# Epoch 464/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.4433 - y1_output_loss: 0.1313 - y2_output_loss: 0.3125 - y1_output_root_mean_squared_error: 0.3612 - y2_output_root_mean_squared_error: 0.5593 - val_loss: 1.7185 - val_y1_output_loss: 0.3144 - val_y2_output_loss: 1.3640 - val_y1_output_root_mean_squared_error: 0.5642 - val_y2_output_root_mean_squared_error: 1.1833
# Epoch 465/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.4875 - y1_output_loss: 0.1301 - y2_output_loss: 0.3765 - y1_output_root_mean_squared_error: 0.3588 - y2_output_root_mean_squared_error: 0.5990 - val_loss: 5.6748 - val_y1_output_loss: 0.7215 - val_y2_output_loss: 4.9147 - val_y1_output_root_mean_squared_error: 0.8511 - val_y2_output_root_mean_squared_error: 2.2249
# Epoch 466/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.4470 - y1_output_loss: 0.1299 - y2_output_loss: 0.3149 - y1_output_root_mean_squared_error: 0.3616 - y2_output_root_mean_squared_error: 0.5624 - val_loss: 0.8981 - val_y1_output_loss: 0.2366 - val_y2_output_loss: 0.6660 - val_y1_output_root_mean_squared_error: 0.4732 - val_y2_output_root_mean_squared_error: 0.8211
# Epoch 467/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.4764 - y1_output_loss: 0.1270 - y2_output_loss: 0.3476 - y1_output_root_mean_squared_error: 0.3579 - y2_output_root_mean_squared_error: 0.5902 - val_loss: 1.0736 - val_y1_output_loss: 0.2500 - val_y2_output_loss: 0.8147 - val_y1_output_root_mean_squared_error: 0.4986 - val_y2_output_root_mean_squared_error: 0.9083
# Epoch 468/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.6173 - y1_output_loss: 0.1481 - y2_output_loss: 0.4672 - y1_output_root_mean_squared_error: 0.3858 - y2_output_root_mean_squared_error: 0.6844 - val_loss: 0.8170 - val_y1_output_loss: 0.1935 - val_y2_output_loss: 0.6156 - val_y1_output_root_mean_squared_error: 0.4354 - val_y2_output_root_mean_squared_error: 0.7921
# Epoch 469/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3280 - y1_output_loss: 0.1170 - y2_output_loss: 0.2102 - y1_output_root_mean_squared_error: 0.3433 - y2_output_root_mean_squared_error: 0.4584 - val_loss: 0.8527 - val_y1_output_loss: 0.2215 - val_y2_output_loss: 0.6316 - val_y1_output_root_mean_squared_error: 0.4586 - val_y2_output_root_mean_squared_error: 0.8015
# Epoch 470/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.4271 - y1_output_loss: 0.1203 - y2_output_loss: 0.3050 - y1_output_root_mean_squared_error: 0.3471 - y2_output_root_mean_squared_error: 0.5538 - val_loss: 0.8826 - val_y1_output_loss: 0.2118 - val_y2_output_loss: 0.6548 - val_y1_output_root_mean_squared_error: 0.4567 - val_y2_output_root_mean_squared_error: 0.8210
# Epoch 471/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.4592 - y1_output_loss: 0.1317 - y2_output_loss: 0.3278 - y1_output_root_mean_squared_error: 0.3631 - y2_output_root_mean_squared_error: 0.5721 - val_loss: 1.2894 - val_y1_output_loss: 0.2824 - val_y2_output_loss: 0.9858 - val_y1_output_root_mean_squared_error: 0.5324 - val_y2_output_root_mean_squared_error: 1.0030
# Epoch 472/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3585 - y1_output_loss: 0.1098 - y2_output_loss: 0.2497 - y1_output_root_mean_squared_error: 0.3295 - y2_output_root_mean_squared_error: 0.5000 - val_loss: 0.8774 - val_y1_output_loss: 0.2144 - val_y2_output_loss: 0.6622 - val_y1_output_root_mean_squared_error: 0.4560 - val_y2_output_root_mean_squared_error: 0.8182
# Epoch 473/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.4695 - y1_output_loss: 0.1340 - y2_output_loss: 0.3330 - y1_output_root_mean_squared_error: 0.3676 - y2_output_root_mean_squared_error: 0.5782 - val_loss: 1.5836 - val_y1_output_loss: 0.2689 - val_y2_output_loss: 1.2848 - val_y1_output_root_mean_squared_error: 0.5130 - val_y2_output_root_mean_squared_error: 1.1491
# Epoch 474/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.5088 - y1_output_loss: 0.1397 - y2_output_loss: 0.3668 - y1_output_root_mean_squared_error: 0.3736 - y2_output_root_mean_squared_error: 0.6077 - val_loss: 1.0351 - val_y1_output_loss: 0.2400 - val_y2_output_loss: 0.7719 - val_y1_output_root_mean_squared_error: 0.4923 - val_y2_output_root_mean_squared_error: 0.8904
# Epoch 475/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.4536 - y1_output_loss: 0.1348 - y2_output_loss: 0.3174 - y1_output_root_mean_squared_error: 0.3679 - y2_output_root_mean_squared_error: 0.5641 - val_loss: 0.8764 - val_y1_output_loss: 0.2362 - val_y2_output_loss: 0.6223 - val_y1_output_root_mean_squared_error: 0.4884 - val_y2_output_root_mean_squared_error: 0.7987
# Epoch 476/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.5402 - y1_output_loss: 0.1466 - y2_output_loss: 0.3924 - y1_output_root_mean_squared_error: 0.3832 - y2_output_root_mean_squared_error: 0.6272 - val_loss: 0.9845 - val_y1_output_loss: 0.2215 - val_y2_output_loss: 0.7621 - val_y1_output_root_mean_squared_error: 0.4666 - val_y2_output_root_mean_squared_error: 0.8757
# Epoch 477/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.4140 - y1_output_loss: 0.1125 - y2_output_loss: 0.2979 - y1_output_root_mean_squared_error: 0.3370 - y2_output_root_mean_squared_error: 0.5481 - val_loss: 1.0506 - val_y1_output_loss: 0.2429 - val_y2_output_loss: 0.7918 - val_y1_output_root_mean_squared_error: 0.4924 - val_y2_output_root_mean_squared_error: 0.8990
# Epoch 478/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.4598 - y1_output_loss: 0.1319 - y2_output_loss: 0.3264 - y1_output_root_mean_squared_error: 0.3628 - y2_output_root_mean_squared_error: 0.5728 - val_loss: 0.8197 - val_y1_output_loss: 0.2135 - val_y2_output_loss: 0.5930 - val_y1_output_root_mean_squared_error: 0.4599 - val_y2_output_root_mean_squared_error: 0.7799
# Epoch 479/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3469 - y1_output_loss: 0.1116 - y2_output_loss: 0.2328 - y1_output_root_mean_squared_error: 0.3350 - y2_output_root_mean_squared_error: 0.4845 - val_loss: 1.0358 - val_y1_output_loss: 0.2442 - val_y2_output_loss: 0.7723 - val_y1_output_root_mean_squared_error: 0.4903 - val_y2_output_root_mean_squared_error: 0.8919
# Epoch 480/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3286 - y1_output_loss: 0.1162 - y2_output_loss: 0.2162 - y1_output_root_mean_squared_error: 0.3385 - y2_output_root_mean_squared_error: 0.4626 - val_loss: 1.3429 - val_y1_output_loss: 0.2813 - val_y2_output_loss: 1.0546 - val_y1_output_root_mean_squared_error: 0.5280 - val_y2_output_root_mean_squared_error: 1.0315
# Epoch 481/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.3810 - y1_output_loss: 0.1246 - y2_output_loss: 0.2539 - y1_output_root_mean_squared_error: 0.3543 - y2_output_root_mean_squared_error: 0.5054 - val_loss: 1.0561 - val_y1_output_loss: 0.1980 - val_y2_output_loss: 0.8323 - val_y1_output_root_mean_squared_error: 0.4466 - val_y2_output_root_mean_squared_error: 0.9255
# Epoch 482/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3575 - y1_output_loss: 0.1236 - y2_output_loss: 0.2311 - y1_output_root_mean_squared_error: 0.3527 - y2_output_root_mean_squared_error: 0.4828 - val_loss: 1.0109 - val_y1_output_loss: 0.2812 - val_y2_output_loss: 0.7176 - val_y1_output_root_mean_squared_error: 0.5317 - val_y2_output_root_mean_squared_error: 0.8533
# Epoch 483/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.3522 - y1_output_loss: 0.1192 - y2_output_loss: 0.2355 - y1_output_root_mean_squared_error: 0.3436 - y2_output_root_mean_squared_error: 0.4839 - val_loss: 1.8869 - val_y1_output_loss: 0.4257 - val_y2_output_loss: 1.5348 - val_y1_output_root_mean_squared_error: 0.6254 - val_y2_output_root_mean_squared_error: 1.2230
# Epoch 484/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.4043 - y1_output_loss: 0.1244 - y2_output_loss: 0.2861 - y1_output_root_mean_squared_error: 0.3510 - y2_output_root_mean_squared_error: 0.5302 - val_loss: 2.4376 - val_y1_output_loss: 0.4573 - val_y2_output_loss: 1.9459 - val_y1_output_root_mean_squared_error: 0.6799 - val_y2_output_root_mean_squared_error: 1.4055
# Epoch 485/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.5236 - y1_output_loss: 0.1541 - y2_output_loss: 0.3678 - y1_output_root_mean_squared_error: 0.3933 - y2_output_root_mean_squared_error: 0.6074 - val_loss: 0.9656 - val_y1_output_loss: 0.1896 - val_y2_output_loss: 0.7530 - val_y1_output_root_mean_squared_error: 0.4378 - val_y2_output_root_mean_squared_error: 0.8797
# Epoch 486/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4480 - y1_output_loss: 0.1412 - y2_output_loss: 0.3041 - y1_output_root_mean_squared_error: 0.3763 - y2_output_root_mean_squared_error: 0.5535 - val_loss: 0.8440 - val_y1_output_loss: 0.2055 - val_y2_output_loss: 0.6277 - val_y1_output_root_mean_squared_error: 0.4482 - val_y2_output_root_mean_squared_error: 0.8019
# Epoch 487/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3161 - y1_output_loss: 0.1008 - y2_output_loss: 0.2154 - y1_output_root_mean_squared_error: 0.3185 - y2_output_root_mean_squared_error: 0.4633 - val_loss: 0.8523 - val_y1_output_loss: 0.1941 - val_y2_output_loss: 0.6418 - val_y1_output_root_mean_squared_error: 0.4405 - val_y2_output_root_mean_squared_error: 0.8113
# Epoch 488/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.4390 - y1_output_loss: 0.1259 - y2_output_loss: 0.3110 - y1_output_root_mean_squared_error: 0.3563 - y2_output_root_mean_squared_error: 0.5586 - val_loss: 1.1171 - val_y1_output_loss: 0.1932 - val_y2_output_loss: 0.9001 - val_y1_output_root_mean_squared_error: 0.4397 - val_y2_output_root_mean_squared_error: 0.9611
# Epoch 489/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3319 - y1_output_loss: 0.1133 - y2_output_loss: 0.2187 - y1_output_root_mean_squared_error: 0.3361 - y2_output_root_mean_squared_error: 0.4679 - val_loss: 0.9629 - val_y1_output_loss: 0.2240 - val_y2_output_loss: 0.7205 - val_y1_output_root_mean_squared_error: 0.4726 - val_y2_output_root_mean_squared_error: 0.8600
# Epoch 490/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4560 - y1_output_loss: 0.1331 - y2_output_loss: 0.3227 - y1_output_root_mean_squared_error: 0.3664 - y2_output_root_mean_squared_error: 0.5672 - val_loss: 0.8903 - val_y1_output_loss: 0.2336 - val_y2_output_loss: 0.6525 - val_y1_output_root_mean_squared_error: 0.4839 - val_y2_output_root_mean_squared_error: 0.8100
# Epoch 491/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3994 - y1_output_loss: 0.1248 - y2_output_loss: 0.2725 - y1_output_root_mean_squared_error: 0.3547 - y2_output_root_mean_squared_error: 0.5231 - val_loss: 0.8860 - val_y1_output_loss: 0.1825 - val_y2_output_loss: 0.6905 - val_y1_output_root_mean_squared_error: 0.4290 - val_y2_output_root_mean_squared_error: 0.8378
# Epoch 492/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3348 - y1_output_loss: 0.1017 - y2_output_loss: 0.2337 - y1_output_root_mean_squared_error: 0.3199 - y2_output_root_mean_squared_error: 0.4822 - val_loss: 1.1689 - val_y1_output_loss: 0.1922 - val_y2_output_loss: 0.9722 - val_y1_output_root_mean_squared_error: 0.4392 - val_y2_output_root_mean_squared_error: 0.9879
# Epoch 493/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.6153 - y1_output_loss: 0.1564 - y2_output_loss: 0.4563 - y1_output_root_mean_squared_error: 0.3966 - y2_output_root_mean_squared_error: 0.6768 - val_loss: 1.2305 - val_y1_output_loss: 0.2661 - val_y2_output_loss: 0.9316 - val_y1_output_root_mean_squared_error: 0.5171 - val_y2_output_root_mean_squared_error: 0.9814
# Epoch 494/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.4549 - y1_output_loss: 0.1367 - y2_output_loss: 0.3152 - y1_output_root_mean_squared_error: 0.3714 - y2_output_root_mean_squared_error: 0.5630 - val_loss: 1.3221 - val_y1_output_loss: 0.2935 - val_y2_output_loss: 1.0028 - val_y1_output_root_mean_squared_error: 0.5437 - val_y2_output_root_mean_squared_error: 1.0132
# Epoch 495/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.4696 - y1_output_loss: 0.1237 - y2_output_loss: 0.3430 - y1_output_root_mean_squared_error: 0.3533 - y2_output_root_mean_squared_error: 0.5872 - val_loss: 0.9848 - val_y1_output_loss: 0.2626 - val_y2_output_loss: 0.7307 - val_y1_output_root_mean_squared_error: 0.5006 - val_y2_output_root_mean_squared_error: 0.8568
# Epoch 496/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.3770 - y1_output_loss: 0.1152 - y2_output_loss: 0.2595 - y1_output_root_mean_squared_error: 0.3397 - y2_output_root_mean_squared_error: 0.5115 - val_loss: 0.8154 - val_y1_output_loss: 0.1976 - val_y2_output_loss: 0.6061 - val_y1_output_root_mean_squared_error: 0.4414 - val_y2_output_root_mean_squared_error: 0.7877
# Epoch 497/500
# 614/614 [==============================] - 0s 141us/sample - loss: 0.3438 - y1_output_loss: 0.1008 - y2_output_loss: 0.2406 - y1_output_root_mean_squared_error: 0.3178 - y2_output_root_mean_squared_error: 0.4928 - val_loss: 0.8456 - val_y1_output_loss: 0.2224 - val_y2_output_loss: 0.6100 - val_y1_output_root_mean_squared_error: 0.4711 - val_y2_output_root_mean_squared_error: 0.7898
# Epoch 498/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.4267 - y1_output_loss: 0.1188 - y2_output_loss: 0.3107 - y1_output_root_mean_squared_error: 0.3444 - y2_output_root_mean_squared_error: 0.5550 - val_loss: 1.6875 - val_y1_output_loss: 0.2453 - val_y2_output_loss: 1.4148 - val_y1_output_root_mean_squared_error: 0.4929 - val_y2_output_root_mean_squared_error: 1.2019
# Epoch 499/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3426 - y1_output_loss: 0.1126 - y2_output_loss: 0.2317 - y1_output_root_mean_squared_error: 0.3359 - y2_output_root_mean_squared_error: 0.4793 - val_loss: 1.4958 - val_y1_output_loss: 0.2809 - val_y2_output_loss: 1.2392 - val_y1_output_root_mean_squared_error: 0.5195 - val_y2_output_root_mean_squared_error: 1.1072
# Epoch 500/500
# 614/614 [==============================] - 0s 150us/sample - loss: 0.5506 - y1_output_loss: 0.1659 - y2_output_loss: 0.3840 - y1_output_root_mean_squared_error: 0.4086 - y2_output_root_mean_squared_error: 0.6193 - val_loss: 1.1672 - val_y1_output_loss: 0.2659 - val_y2_output_loss: 0.8800 - val_y1_output_root_mean_squared_error: 0.5087 - val_y2_output_root_mean_squared_error: 0.9531

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 34us/sample - loss: 1.1672 - y1_output_loss: 0.2591 - y2_output_loss: 0.9033 - y1_output_root_mean_squared_error: 0.5087 - y2_output_root_mean_squared_error: 0.9531
# Loss = 1.1671593220202954, Y1_loss = 0.2590905725955963, Y1_mse = 0.5087284445762634, Y2_loss = 0.9033398628234863, Y2_mse = 0.9530764222145081

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
